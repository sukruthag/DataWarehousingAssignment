# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("/kaggle/input/walmart-dataset-retail/Walmart_Store_sales.csv")

# %%
data.head()
# Out:
#    Store        Date  Weekly_Sales  Holiday_Flag  Temperature  Fuel_Price  \
# 0      1  05-02-2010    1643690.90             0        42.31       2.572
# 1      1  12-02-2010    1641957.44             1        38.51       2.548
# 2      1  19-02-2010    1611968.17             0        39.93       2.514
# 3      1  26-02-2010    1409727.59             0        46.63       2.561
# 4      1  05-03-2010    1554806.68             0        46.50       2.625
#
#           CPI  Unemployment
# 0  211.096358         8.106
# 1  211.242170         8.106
# 2  211.289143         8.106
# 3  211.319643         8.106
# 4  211.350143         8.106

# %%
data.isnull().sum()
# Out:
# Store           0
# Date            0
# Weekly_Sales    0
# Holiday_Flag    0
# Temperature     0
# Fuel_Price      0
# CPI             0
# Unemployment    0
# dtype: int64

# %% [markdown]
# Boxplots are visual methods to detect outliers. Box plots is one of the many ways to visualize data distribution. Box plot plots the q1 (25th percentile), q2 (50th percentile or median) and q3 (75th percentile) of the data along with (q1–1.5*(q3-q1)) and (q3+1.5*(q3-q1)). Outliers, if any, are plotted as points above and below the plot.

# %%
data.plot(kind = "box", subplots = True, layout=(7,2),figsize=(15,20))
# Out:
# Store              AxesSubplot(0.125,0.787927;0.352273x0.0920732)
# Weekly_Sales    AxesSubplot(0.547727,0.787927;0.352273x0.0920732)
# Holiday_Flag       AxesSubplot(0.125,0.677439;0.352273x0.0920732)
# Temperature     AxesSubplot(0.547727,0.677439;0.352273x0.0920732)
# Fuel_Price         AxesSubplot(0.125,0.566951;0.352273x0.0920732)
# CPI             AxesSubplot(0.547727,0.566951;0.352273x0.0920732)
# Unemployment       AxesSubplot(0.125,0.456463;0.352273x0.0920732)
# dtype: object

# %%
df['Fuel_Price'].mean()
# Out:
# 3.358606837606838

# %%
df['Fuel_Price'].std()
# Out:
# 0.4590197071928525

# %%
lower_limit = df['Fuel_Price'].mean() - 3*df['Fuel_Price'].std()
upper_limit = df['Fuel_Price'].mean() + 3*df['Fuel_Price'].std()
print(lower_limit)
print(upper_limit)
# Out:
# 1.9815477160282806
# 4.735665959185395

# %%
df_scores = df['Fuel_Price']
df_scores_filtered=df_scores[(df_scores>lower_limit)&(df_scores<upper_limit)]
print(df_scores_filtered)
# Out:
# 0       2.572
# 1       2.548
# 2       2.514
# 3       2.561
# 4       2.625
#         ...
# 6430    3.997
# 6431    3.985
# 6432    4.000
# 6433    3.969
# 6434    3.882
# Name: Fuel_Price, Length: 6435, dtype: float64
